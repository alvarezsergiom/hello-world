# %%
x = int(input("What is x? "))
y = int(input("What is y? "))
if x < y: # bolean expresssion  the colon is used for indentation  which is executed in the next line if this line is true
    
    print("x is less than y")
if y > y:
    print ("x is greater than y")
if x == y:
    print ("x is equal to y")
# Out:
# What is x?  2
# What is y?  3
# x is less than y

# %% [markdown]
# ![image.png](attachment:55e93f6a-1835-45d7-82cf-15f34d3b213b.png)

# %% [markdown]
# # Elif
# contraction of else and if, meaning sino

# %%
x = int(input("What's x? "))
y = int(input("What's y? "))

if x < y:
    print("x is less than y")
elif x > y:
    print("x is greater than y")
elif x == y:
    print("x is equal to y")
# Out:
# What's x? 1
# What's y? 2
# x is less than y

# %% [markdown]
# ![image.png](attachment:43c3d817-0a21-4fad-b1b4-5ca6c96cb84a.png)

# %% [markdown]
# This way is more efficientto write the code

# %% [markdown]
# Else   > means els just asume... and print the answer.  We can just logically say that x is equal to y

# %% [markdown]
# ![image.png](attachment:0ce7e274-c432-4d81-ae2f-4796de8ee0fe.png)

# %%
x = int(input("What's x? "))
y = int(input("What's y? "))

if x < y:
    print("x is less than y")
elif x > y:
    print("x is greater than y")
else:
    print("x is equal to y")
# Out:
# What's x?  2
# What's y?  2
# x is equal to y

# %% [markdown]
# ## OR function

# %%
x = int(input("What's x? "))
y = int(input("What's y? "))

if x < y or x > y:
    print("x is not equal to y")
else:
    print("x is equal to y")
# Out:
# What's x?  2
# What's y?  4
# x is not equal to y

# %% [markdown]
# ![image.png](attachment:5bf61d0a-50b2-4501-a007-ee52af0cfb9e.png)

# %% [markdown]
# !=   Not equal

# %%
x = int(input("What's x? "))
y = int(input("What's y? "))

if x != y:
    print("x is not equal to y")
else:
    print("x is equal to y")
# Out:
# What's x?  3
# What's y?  2
# x is not equal to y

# %% [markdown]
# ![image.png](attachment:7f645935-1f7c-40dc-bc54-05a1cd4969b5.png)

# %% [markdown]
# ## AND function

# %%
score = int(input("Score: "))

if score >= 90 and score <= 100:
    print("Grade: A")
elif score >= 80 and score <90:
    print("Grade: B")
elif score >= 70 and score <80:
    print("Grade: C")
elif score >= 60 and score <70:
    print("Grade: D")
else:
    print("Grade: F")
# Out:
# Score:  1
# Grade: F

# %% [markdown]
# # Changing comparison operators... making the code cleaner

# %%
score = int(input("Score: "))

if 90 <= score <= 100:
    print("Grade: A")
elif 80 <= score <90:
    print("Grade: B")
elif 70 <= score <80:
    print("Grade: C")
elif 60 <= score <70:
    print("Grade: D")
else:
    print("Grade: F")
# Out:
# Score:  76
# Grade: C

# %% [markdown]
# ## Improving the code asking only one question

# %%
score = int(input("Score: "))

if score >= 90:
    print("Grade: A")
elif score >= 80:
    print("Grade: B")
elif score >= 70:
    print("Grade: C")
elif score >=60:
    print("Grade: D")
else:
    print("Grade: F")
# Out:
# Score:  68
# Grade: D

# %% [markdown]
# # Parity
# ### It evaluates if a number is even or odd

# %%
x = int(input("What's x?"))
y = int(input("What's y?"))
remainder = x % y
print (remainder)
# Out:
# What's x? 10
# What's y? 3
# 1

# %%
x = int(input("What's x? "))
if x % 2 ==0: # modulo operator it calculates the remainder of de division of 2 numbers
    print("Even")
else:
    print("Odd")
# Out:
# What's x?  3
# Odd

# %% [markdown]
# # Boolean

# %%
def main():
    x = int(input("What's x? "))
    if is_even(x):
        print("Even")
    else:
        print("Odd")
def is_even(n):
    if n % 2 == 0:
        return True
    else:
        return False
main()
# Out:
# What's x?  3
# Odd

# %% [markdown]
# ## In python these 4 lines can be collapsed in one line question

# %%
def main():
    x = int(input("What's x? "))
    if is_even(x):
        print("Even")
    else:
        print("Odd")
def is_even(n):
    return True if n % 2 == 0 else False

main()
# Out:
# What's x?  2
# Even

# %% [markdown]
# ## This can be refined still further

# %%
def main():
    x = int(input("What's x? "))
    if is_even(x):
        print("Even")
    else:
        print("Odd")
def is_even(n):
    return n % 2 == 0

main()
# Out:
# What's x?  46
# Even

# %% [markdown]
# # Match function. Is another syntax to expres the same idea of booleans

# %%
name = input("What's your name? ")
if name == "Harry":
    print("Gryffindor")
elif name == "Hermione":
    print("Gryffindor")
elif name == "Ron":
    print("Gryffindor")
elif name == "Draco":
    print("Slytherin")
else:
    print("who?")
# Out:
# What's your name?  Ron
# Gryffindor

# %% [markdown]
# ## We can reduce redundancy

# %%
name = input("What's your name? ")
if name == "Harry" or "Hermione" or "Ron":
    print("Gryffindor")
elif name == "Draco":
    print("Slytherin")
else:
    print("who?")
# Out:
# What's your name?  Hermione
# Gryffindor

# %% [markdown]
# ## There is also another improvement using match

# %%
name = input("What's your name? ")

match name:
    case "Harry":
        print("Gryffindor")
    case "Hermione":
        print("Gryffindor")
    case "Ron":
        print("Gryffindor")
    case "Draco":
        print("Slytherin")
    case _: # Whatever other case is represented as "_"
        print("Who?")
# Out:
#   File "C:\Users\Familia\AppData\Local\Temp\ipykernel_20792\728661661.py", line 3
#     match name:
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## There is a way to improve this match function code

# %%
name = input("What's your name? ")

match name:
    case "Harry" |"Hermione" | "Ron": # Singole vertical bar | is used to say the equivalent
        print("Gryffindor")
    case "Draco":
        print("Slytherin")
    case _:
        print("Who?")
# Out:
#   File "C:\Users\Familia\AppData\Local\Temp\ipykernel_20792\3308977639.py", line 3
#     match name:
#           ^
# SyntaxError: invalid syntax

# %%
from platform import python_version
print(python_version())
# Out:
# 3.9.16

# %% [markdown]
# # Summing Up
# You now have the power within Python to use conditional statements to ask questions and have your program take action accordingly. In this lecture, we discussed…
#
# Conditionals;
# if Statements;
# Control flow, elif, and else;
# or;
# and;
# Modulo;
# Creating your own function;
# Pythonic coding;
# and match.
# More details are in the following link:
# https://cs50.harvard.edu/python/2022/notes/1/

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1 Deep question of life
# In deep.py, implement a program that prompts the user for the answer to the Great Question of Life, the Universe and Everything, outputting Yes if the user inputs 42 or (case-insensitively) forty-two or forty two. Otherwise output No.
#
# Hints

# %%
x = str(input("What's the  answer to the Great Question of Life, the Universe and Everything? "))
x = x.lower().lstrip()
if x == "42" or x == "forty-two" or x =="forty two":
    print("Yes")
else:
    print("No")
# Out:
# What's the  answer to the Great Question of Life, the Universe and Everything?     Forty-tWO
# Yes

# %% [markdown]
# ## 2 Bank exercise
# In season 7, episode 24 of Seinfeld, Kramer visits a bank that promises to give $100 to anyone who isn’t greeted with a “hello.” Kramer is instead greeted with a “hey,” which he insists isn’t a “hello,” and so he asks for $100. The bank’s manager proposes a compromise: “You got a greeting that starts with an ‘h,’ how does $20 sound?” Kramer accepts.
#
# In a file called bank.py, implement a program that prompts the user for a greeting. If the greeting starts with “hello”, output $0. If the greeting starts with an “h” (but not “hello”), output $20. Otherwise, output $100. Ignore any leading whitespace in the user’s greeting, and treat the user’s greeting case-insensitively.

# %%
x = str(input("Greeting: "))
x = x.lower().lstrip()

if x.startswith("hello") == True:
    print(0)
elif x.startswith("h") == True:
    print(20)
else:
    print(100)
# Out:
# Greeting:  hELLO
# 0

# %% [markdown]
# ## 3 File extensions exercise
# Even though Windows and macOS sometimes hide them, most files have file extensions, a suffix that starts with a period (.) at the end of their name. For instance, file names for GIFs end with .gif, and file names for JPEGs end with .jpg or .jpeg. When you double-click on a file to open it, your computer uses its file extension to determine which program to launch.
#
# Web browsers, by contrast, rely on media types, formerly known as MIME types, to determine how to display files that live on the web. When you download a file from a web server, that server sends an HTTP header, along with the file itself, indicating the file’s media type. For instance, the media type for a GIF is image/gif, and the media type for a JPEG is image/jpeg. To determine the media type for a file, a web server typically looks at the file’s extension, mapping one to the other.
#
# See developer.mozilla.org/en-US/docs/Web/HTTP/Basics_of_HTTP/MIME_types/Common_types for common types.
#
# In a file called extensions.py, implement a program that prompts the user for the name of a file and then outputs that file’s media type if the file’s name ends, case-insensitively, in any of these suffixes:
#
# .gif
# .jpg
# .jpeg
# .png
# .pdf
# .txt
# .zip
# If the file’s name ends with some other suffix or has no suffix at all, output application/octet-stream instead, which is a common default.

# %%
x = str(input("File name: "))
if x.endswith(".gif") == True:
    print("image/gif")
elif x.endswith(".jpg") or x.endswith(".jpeg")== True:
    print("image/jpeg")
elif x.endswith(".png") == True:
    print("image/png")
elif x.endswith(".pdf") == True:
    print("application/pdf")
elif x.endswith(".txt") == True:
    print("text/plain")
elif x.endswith(".zip") == True:
    print("application/zip")
else:
    print("application/octet-stream")
# Out:
# File name:  sergio.jpeg
# image/jpeg

# %% [markdown]
# ## 4 Math interpreter exercise
# Python already supports math, whereby you can write code to add, subtract, multiply, or divide values and even variables. But let’s write a program that enables users to do math, even without knowing Python.
#
# In a file called interpreter.py, implement a program that prompts the user for an arithmetic expression and then calculates and outputs the result as a floating-point value formatted to one decimal place. Assume that the user’s input will be formatted as x y z, with one space between x and y and one space between y and z, wherein:
#
# x is an integer
# y is +, -, *, or /
# z is an integer
# For instance, if the user inputs 1 + 1, your program should output 2.0. Assume that, if y is /, then z will not be 0.
#
# Note that, just as python itself is an interpreter for Python, so will your interpreter.py be an interpreter for math!

# %%
n = input("Expression: ")
x, y, z = n.split(" ")
if y == "+":
    print(float(x) + float(z))
elif y == "-":
    print(float(x) - float(z))
elif y == "*":
    print (float(x) * float(z))
else:
    print (round(float(x) / float(z), 1))
# Out:
# Expression:  5 + 6
# 11.0

# %% [markdown]
# ## 5 Meal exercise
# Suppose that you’re in a country where it’s customary to eat breakfast between 7:00 and 8:00, lunch between 12:00 and 13:00, and dinner between 18:00 and 19:00. Wouldn’t it be nice if you had a program that could tell you what to eat when?
#
# In meal.py, implement a program that prompts the user for a time and outputs whether it’s breakfast time, lunch time, or dinner time. If it’s not time for a meal, don’t output anything at all. Assume that the user’s input will be formatted in 24-hour time as #:## or ##:##. And assume that each meal’s time range is inclusive. For instance, whether it’s 7:00, 7:01, 7:59, or 8:00, or anytime in between, it’s time for breakfast.
#
# Structure your program per the below, wherein convert is a function (that can be called by main) that converts time, a str in 24-hour format, to the corresponding number of hours as a float. For instance, given a time like "7:30" (i.e., 7 hours and 30 minutes), convert should return 7.5 (i.e., 7.5 hours).

# %%
# Defining main function
def main():
    # asking user input
    x = input("What time is it? ")
    # calling convert function
    convert(x)

# defining convert function
def convert(time):
    hours, minutes = time.split(":")
    conv = float(hours) + float(minutes)/60

    if 7 <= conv <= 8:
        print("breakfast time")
    elif 12<= conv<=13:
        print("lunch time")
    elif 18<= conv <=19:
        print("dinner time")
    else:
        print()


if __name__ == "__main__":
    main()
# Out:
# What time is it?  7:30
# breakfast time

# %% [markdown]
# ### Another way

# %%
# Defining main function
def main():
    # asking user input
    x = input("What time is it? ")
    # calling convert function
    ans = convert(x)
    if 7 <= ans <= 8:
        print("breakfast time")
    elif 12<= ans <=13:
        print("lunch time")
    elif 18<= ans <=19:
        print("dinner time")
    
# defining convert function
def convert(time):
    hours, minutes = time.split(":")
    min_conv = float(minutes) / 60
    return float(hours) + min_conv
    #conv = float(hours) + float(minutes)/60



if __name__ == "__main__":
    main()
# Out:
# What time is it?  12:15
# lunch time
