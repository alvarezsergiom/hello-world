# %% [markdown]
# # Loops

# %%
print("meow")
print("meow")
print("meow")
# Out:
# meow
# meow
# meow

# %% [markdown]
# ![image.png](attachment:4f9fa44a-915f-4d77-ac52-761c6e1364d6.png)

# %% [markdown]
# ## While
# ### One way to express a loop

# %%
i = 3
while i != 0: # != means different
    print("meow") # if we have an accidental loop control C can cancel or interrupt the process
    i= i - 1
# Out:
# meow
# meow
# meow

# %% [markdown]
# ![image.png](attachment:fa6fe6ca-b592-4a15-94cf-293f2d449501.png)

# %% [markdown]
# ### Another way of coding

# %%
i = 1
while i<= 3:
    print("meow")
    i = i + 1
# Out:
# meow
# meow
# meow

# %% [markdown]
# ![image.png](attachment:5e6f83f1-0c4d-4a7e-8ce6-a300fa043ab2.png)

# %% [markdown]
# ### Most programmers start counting from zero

# %%
i = 0
while i< 3:
    print("meow")
    i = i + 1
# Out:
# meow
# meow
# meow

# %% [markdown]
# ### Using  += instead for being even more succint

# %%
i = 1
while i<= 3:
    print("meow")
    i += 1
# Out:
# meow
# meow
# meow

# %% [markdown]
# ![image.png](attachment:7b162475-259f-423f-8561-6dadb5bd9064.png)

# %% [markdown]
# ## For and list
# For allows you to iterate over a list of items

# %%
for i in [0, 1, 2]:
    print("meow")
 # square brackets represent a list
# Out:
# meow
# meow
# meow

# %% [markdown]
# ### Range

# %%
# We can also use the range function for improvement
for i in range(3):
    print("meow")
# Out:
# meow
# meow
# meow

# %% [markdown]
# ### (_)  as variable
# underscore symbol (_)...   When you  use a variable that is just necessary in order to use a feature you can use but you do not care about it later

# %%
for _ in range(3):
    print("meow")
# Out:
# meow
# meow
# meow

# %%
print("meow \n" * 3, end = "") # \n indicates to write in a new line. Als to override the default additional blank line at the end we specify to put nothing at the end
# Out:
# meow
# meow
# meow

# %% [markdown]
# ## While loop for validating an input.
# Used when we want to tet a user input that matches a certain expectation we do have
# This is a very common paradigm in python

# %%
while True:
    n = int(input("What's n?"))
    if n < 0:
        continue
    else:
        break # to break from a loop
# Out:
# What's n? -1
# What's n? -2
# What's n? -3
# What's n? 4

# %%
# To tighten it up further we can ask if n>0, then break
while True:
    n = int(input("What's n?"))
    if n > 0:
        break # this has the intend to brake the loop

for _ in range(n): # to meow the number of times intended
    print("meow")
# Out:
# What's n? 2
# meow
# meow

# %% [markdown]
# ### Defining a Function

# %%
def main():
    meow(3)
    
    
def meow(n):
    for _ in range(n):
        print("meow")
        
        
main()
# Out:
# meow
# meow
# meow

# %% [markdown]
# ### Improving the code

# %%
def main():
    number = get_number()
    meow(number)


#Defining a variable number
def get_number():
    while True:
        n = int(input("What's n? "))
        if n > 0:
            break # to get out of the loop or stop the code. Instead of breaking we can put directly return.
    return n    # Return in python return explicitly a value in code to the user

def meow(n): # defines function meow
    for _ in range(n):
        print("meow")


main()
# Out:
# What's n?  4
# meow
# meow
# meow
# meow

# %% [markdown]
# ### Same code but using directly return

# %%
def main():
    number = get_number()
    meow(number)


#Defining a variable number
def get_number():
    while True:
        n = int(input("What's n? "))
        if n > 0:
            return n # to get out of the loop or stop the code. Instead of breaking we can put directly return.
# Return in python return explicitly a value in code to the user

def meow(n): # defines function meow
    for _ in range(n):
        print("meow")


main()
# Out:
# What's n?  5
# meow
# meow
# meow
# meow
# meow

# %% [markdown]
# ## List

# %%
students = ["Hermione", "Harry", "Ron"]  #brackets because is a list
for student in students:
    print(student)
# Out:
# Hermione
# Harry
# Ron

# %% [markdown]
# ## Len
# Supose we want to iterate using numbers instead we can use this function
# tell you the lenght of a list

# %%
students = ["Hermione", "Harry", "Ron"]  #brackets because is a list
for i in range(len(students)):
    print(students[i])
# Out:
# Hermione
# Harry
# Ron

# %% [markdown]
# ### If we whant to make a ranking

# %%
#Len can be used  for print multiple strings of a list multiple times using range and for
students = ["Hermione", "Harry", "Ron"]  #brackets because is a list
for i in range(len(students)): #len purpose is to tell how long is a list to subsequently use range which gives the range of values in the list
    print(i, students[i])
# Out:
# 0 Hermione
# 1 Harry
# 2 Ron

# %% [markdown]
# ### Improving the ranking
# As indexing begin from zero is recommended to modify it to start from 1

# %%
#Len can be used  for print multiple strings of a list multiple times using range and for
students = ["Hermione", "Harry", "Ron"]  #brackets because is a list
for i in range(len(students)): #len purpose is to tell how long is a list to subsequently use range which gives the range of values in the list
    print(i+1, students[i])
# Out:
# 1 Hermione
# 2 Harry
# 3 Ron

# %% [markdown]
# # DICTIONARIES dict
# Dictionaries, are data structures thah allow you to associate keys with their values. It uses curly braces

# %%
# for dictionary we use curly braces {keys:values, ....}
students = {
    "Hermione": "Gryffindor",
    "Harry": "Gryffindor",
    "Ron": "Gryffindor",
    "Draco": "Slytherin",
}

print (students["Hermione"])
print (students["Harry"])
print (students["Ron"])
print (students["Draco"])
# Out:
# Gryffindor
# Gryffindor
# Gryffindor
# Slytherin

# %% [markdown]
# ## When using for in dictionarries, by design it iterates over all of the keys

# %%
# for dictionary we use curly braces {keys:values, ....}
students = {
    "Hermione": "Gryffindor",
    "Harry": "Gryffindor",
    "Ron": "Gryffindor",
    "Draco": "Slytherin",
}

for student in students:
    print(student)
# Out:
# Hermione
# Harry
# Ron
# Draco

# %% [markdown]
# ## To print values we have to modify the code

# %%
students = {
    "Hermione": "Gryffindor",
    "Harry": "Gryffindor",
    "Ron": "Gryffindor",
    "Draco": "Slytherin",
}

for student in students:
    print(students[student])
# Out:
# Gryffindor
# Gryffindor
# Gryffindor
# Slytherin

# %%
# We can print keys and values, using commas as separators
students = {
    "Hermione": "Gryffindor",
    "Harry": "Gryffindor",
    "Ron": "Gryffindor",
    "Draco": "Slytherin",
}

for student in students:
    print(student, students[student], sep = ", ")
# Out:
# Hermione, Gryffindor
# Harry, Gryffindor
# Ron, Gryffindor
# Draco, Slytherin

# %% [markdown]
# ## List of dictionaries
#  enhanncing with more data

# %%
# in this case we have several dictionaries listed in between []
students = [
    {"name": "Hermione", "house": "Gryffindor", "patronus": "Otter"},
    {"name": "Harry", "house": "Gryffindor", "patronus": "stag"},
    {"name": "Ron", "house": "Gryffindor", "patronus": "Jack Russell Terrier"},
    {"name": "Draco", "house": "Slytherin", "patronus": None}  #special command that means that here is no data value
]

for student in students:
    print(student["name"], student["house"], student["patronus"], sep=", ") # separator help with cleanliness
# Out:
# Hermione, Gryffindor, Otter
# Harry, Gryffindor, stag
# Ron, Gryffindor, Jack Russell Terrier
# Draco, Slytherin, None

# %% [markdown]
# ## Nested loops
#
# To iterate more complicated problems. i.e. to create columns

# %%
for _ in range(3):
    print("#")
# Out:
# #
# #
# #

# %%
def main():
    print_column(3)
    
    
def print_column(height):
    for _ in range(height):
        print("#")
        
        
main()
# Out:
# #
# #
# #

# %%
# Another alternative

def main():
    print_column(4)
    
    
def print_column(height):
    print("#\n" * height, end="")
        
        
main()
# Out:
# #
# #
# #
# #

# %%
# Now for horizontal
def main():
    print_row(4)
    
    
def print_row(width):
        print("?" * width)
    
    
    
main()
# Out:
# ????

# %%
# Now for squares
def main():
    print_square(3)
    
def print_square(size):
    #for each row in square
        for i in range(size):
            #for each brick in row
            for j in range(size):
                #print brick
                print("#", end="")
            #  this print next line at the end of the loop. That is why indentation is important 
            print()
    
    
    
main()
# Out:
# ###
# ###
# ###

# %%
# it can also be split in different piecesto to solve with 
def main():
    print_square(3)
    
def print_square(size):
    #for each row in square
        for i in range(size):
            print_row(size)
def print_row(width):
    print("#" * width)
           
        
main()
# Out:
# ###
# ###
# ###

# %% [markdown]
# # Set2 Excercises
# ## CamelCase

# %% [markdown]
# In some languages, it’s common to use camel case (otherwise known as “mixed case”) for variables’ names when those names comprise multiple words, whereby the first letter of the first word is lowercase but the first letter of each subsequent word is uppercase. For instance, whereas a variable for a user’s name might be called name, a variable for a user’s first name might be called firstName, and a variable for a user’s preferred first name (e.g., nickname) might be called preferredFirstName.
#
# Python, by contrast, recommends snake case, whereby words are instead separated by underscores (_), with all letters in lowercase. For instance, those same variables would be called name, first_name, and preferred_first_name, respectively, in Python.
#
# In a file called camel.py, implement a program that prompts the user for the name of a variable in camel case and outputs the corresponding name in snake case. Assume that the user’s input will indeed be in camel case.

# %%
cC = input("camelCase: ")

#Print "snake_case"
print("snake_case: ", end="" ) # we specify end"" to avoid writting in next line

#search in each word of the string upercases and replace with _ and lowercase, else print lowercase
for c in cC:
    if c.isupper():
        print("_"+c.lower(), end="")
    else:
        print(c, end="")
# Out:
# camelCase:  juanPerez
# snake_case: juan_perez

# %%
# another way to solve camelCase exercise
def main():
#requesting input
    camelCase = input("camelCase: ")
    #printing snake_case
    print ("snake_case: ", end="")
    #calling snake_call function's result
    snake_case(camelCase)
# loop to find uppercase and convert them to lowercase, including underscore
def snake_case(cC):
    for c in cC:
        if c.isupper():
            print("_"+c.lower(), end="")
        else:
            print (c, end="")
    print()

main()
# Out:
# camelCase:  sergioAlvarez
# snake_case: sergio_alvarez

# %%
# another way to solve camelCase exercise
def main():
#requesting input
    cC = input("camelCase: ")
    
    #printing snake_case
    print ("snake_case: ", end="")
    #calling snake_call function's result
    printsnake_case(cC)
# loop to find uppercase and convert them to lowercase, including underscore
def printsnake_case(camelCase):
    for c in camelCase:
        if c.isupper():
            print("_"+c.lower(), end="")
        else:
            print (c, end="")
    print()

main()
# Out:
# camelCase:  sergioAlvarez
# snake_case: sergio_alvarez

# %% [markdown]
# ## Coke Machine
# Suppose that a machine sells bottles of Coca-Cola (Coke) for 50 cents and only accepts coins in these denominations: 25 cents, 10 cents, and 5 cents.
#
# In a file called coke.py, implement a program that prompts the user to insert a coin, one at a time, each time informing the user of the amount due. Once the user has inputted at least 50 cents, output how many cents in change the user is owed. Assume that the user will only input integers, and ignore any integer that isn’t an accepted denomination.

# %%
print("Amount Due: 50")
# variable  to keep track
ad = 50
# loop
while True:
    # ask user insert coin
    cr = int(input("Insert Coin: "))
    # checking if coin is 25, 10 or 5 cents
    if cr > 0 and ad > 0:
        # substracting credit from amount due
        ad = ad - cr
        print("Amount Due: " + str(ad))
    if ad <= 0:
                print("Change Owed: " + str(ad*-1))
                break
# Out:
# Amount Due: 50
# Insert Coin:  25
# Amount Due: 25
# Insert Coin:  20
# Amount Due: 5
# Insert Coin:  20
# Amount Due: -15
# Change Owed: 15

# %%
# variable  to keep track
ad = 50
# loop
while ad > 0:
    print("Amount Due: ", ad)
    # ask user insert coin
    cr = int(input("Insert Coin: "))
    # checking if coin is 25, 10 or 5 cents
    if 25 == cr or 10 == cr or 5 == cr:
        # substracting credit from amount due
        ad -= cr
print("Change Owed: " + str(abs(ad)))
# Out:
# Amount Due:  50
# Insert Coin:  25
# Amount Due:  25
# Insert Coin:  5
# Amount Due:  20
# Insert Coin:  25
# Change Owed: 5

# %% [markdown]
# ### Other option

# %%
# Creating a variable to keep track
ad = 50
#Loop until amount due is greater than zero
while ad > 0:
    #print the amount due
    print("Amount Due: ", ad)
    #Ask the user to insert coins
    coin = int(input("insert Coin: "))
    #Check if the coins are valid
    if coin in [25, 10, 5]:
    #If the coins are valid substract form amount
        ad = ad - coin 
#computing change
change = abs(ad)
#print the change Owed
print("change Owed: ", change)
# Out:
# Amount Due:  50
# insert Coin:  25
# Amount Due:  25
# insert Coin:  25
# Change owed:  0

# %% [markdown]
# ## Just setting up my twttr
# When texting or tweeting, it’s not uncommon to shorten words to save time or space, as by omitting vowels, much like Twitter was originally called twttr. In a file called twttr.py, implement a program that prompts the user for a str of text and then outputs that same text but with all vowels (A, E, I, O, and U) omitted, whether inputted in uppercase or lowercase.

# %%
# Creating while loop
TWITTER = input("Input: ")
# lowercase
twitter = TWITTER.lower()

# finding vowels in twitter
vowels = ['a', 'e', 'i', 'o', 'u']
# looping
for x in twitter: #para que funcione el codigo del loop,tanto el nombre de esta variable como la que esta dos lineas abajo debe de ser igual 
    #eliminar en cada letra de la palabra las vocales
    if x in vowels:
        twitter = twitter.replace(x, "")
print('resultado: ',twitter)
# Out:
# Input:  HolaSergio
# resultado:  hlsrg

# %% [markdown]
# ### alternativa con logica inversa. Imprimir si no hay vocales en la palabra

# %%
# Creating while loop
twitter = input("Input: ")
# lowercase
twitter = twitter.lower()
# finding vowels in twitter
vowels = ['a', 'e', 'i', 'o', 'u']
# looping
for c in twitter:
    if c not in vowels:
        #twttr = c.replace(c, '')
        # printing twitter
        print(c, end="")
# Out:
# Input:  cLARO QUE sI
# clr q s

# %% [markdown]
# ## Vanity Plates
# In Massachusetts, home to Harvard University, it’s possible to request a vanity license plate for your car, with your choice of letters and numbers instead of random ones. Among the requirements, though, are:
#
# “All vanity plates must start with at least two letters.”
# “… vanity plates may contain a maximum of 6 characters (letters or numbers) and a minimum of 2 characters.”
# “Numbers cannot be used in the middle of a plate; they must come at the end. For example, AAA222 would be an acceptable … vanity plate; AAA22A would not be acceptable. The first number used cannot be a ‘0’.”
# “No periods, spaces, or punctuation marks are allowed.”
# In plates.py, implement a program that prompts the user for a vanity plate and then output Valid if meets all of the requirements or Invalid if it does not. Assume that any letters in the user’s input will be uppercase. Structure your program per the below, wherein is_valid returns True if s meets all requirements and False if it does not. Assume that s will be a str. You’re welcome to implement additional functions for is_valid to call (e.g., one function per requirement).

# %%
def main():
    plate = input("Plate: ")
    if is_valid(plate):
        print("Valid")
    else:
        print("Invalid")


def is_valid(s):
    # Conditions for validity
    if len_2and6(plate) and s.isupper():
        #print S
        print(s)
def len_2and6(l)
#counter
counter = 0
for l in plate:
    counter += 1:
    if 2<= l<=6:
        return

    ...


main()
# Out:
#   File "C:\Users\Familia\AppData\Local\Temp\ipykernel_4212\348999013.py", line 14
#     def len_2and6(l)
#                     ^
# SyntaxError: invalid syntax

# %%
def main():
    plate = input("palabra: ")
    len_word(plate)
  
def len_word(plate):
#counter
    counter = 0
    for l in plate:
        counter += 1
        #return value
        #return counter
    if 2<= counter <=6:
        print(counter)
        
        
        
main()
# Out:
# palabra:  hola
# 4

# %%
#Definir el nombre
nombre = input("palabra: ")
#Contador letras
contador = 0
#For para recorrer el nombre
for i in nombre:
    contador += 1
#Imprimr resultado

#if contador >4 print
if contador > 4:
    print(contador)
# Out:
# palabra:  HOLASI
# 6

# %%
string = input("palabra: ")
def contcadena(string):
    contar = 0
    
    for p in string:
        if p.isalpha():
            contar += 1
    return contar
letter = contcadena(string)

print ("letras ",letter)
# Out:
# palabra:  holasdfja;lskdfj
# letras  15

# %%
string = input("palabra: ")

def contcadena(string):
    contar = 0
    
    for p in string:
        if p.isalpha():
            contar += 1
    return contar

letter = contcadena(string)

print("letras ", letter)
# Out:
# palabra:  hola
# letras  4

# %%
# Definir una función que recibe una palabra como argumento
def contar_letras(palabra):
  # Usar la función len para obtener el número de letras de la palabra
  numero = len(palabra)
  # Devolver el número de letras
  return numero

# Probar la función con una palabra de ejemplo
palabra = input("palabra: ")
resultado = contar_letras(palabra)
print(f"La palabra {palabra} tiene {resultado} letras.")
# Out:
# palabra:  SERGIO
# La palabra SERGIO tiene 6 letras.
